# %%
# !pip install soccerdata
# Data manipulation
import pandas as pd
import numpy as np
from soccerdata import FBref

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Warnings
import warnings
warnings.filterwarnings('ignore')

# Display settings for Jupyter notebooks (if applicable)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: f'{x:,.2f}')

# Statistical tests and modeling
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Optional: Machine learning setup
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Optional: Working with SQL
import sqlite3
# Out:
# Requirement already satisfied: soccerdata in c:\users\arjun\anaconda3\lib\site-packages (1.8.7)
# Requirement already satisfied: PySocks<2.0.0,>=1.7.1 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (1.7.1)
# Requirement already satisfied: Unidecode<2.0.0,>=1.2.0 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (1.3.8)
# Requirement already satisfied: cloudscraper<2.0.0,>=1.2.71 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (1.2.71)
# Requirement already satisfied: html5lib<2.0,>=1.1 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (1.1)
# Requirement already satisfied: lxml<5.0.0,>=4.9.3 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (4.9.4)
# Requirement already satisfied: packaging<25.0,>=24.1 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (24.1)
# Requirement already satisfied: pandas!=2.1.0,<3.0.0,>=2.0.0 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (2.2.2)
# Requirement already satisfied: requests<3.0,>=2.23 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (13.7.1)
# Requirement already satisfied: undetected-chromedriver<4.0.0,>=3.5.0 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (3.5.5)
# Requirement already satisfied: unicode<3.0,>=2.7 in c:\users\arjun\anaconda3\lib\site-packages (from soccerdata) (2.9)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\arjun\anaconda3\lib\site-packages (from cloudscraper<2.0.0,>=1.2.71->soccerdata) (3.1.2)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in c:\users\arjun\anaconda3\lib\site-packages (from cloudscraper<2.0.0,>=1.2.71->soccerdata) (1.0.0)
# Requirement already satisfied: six>=1.9 in c:\users\arjun\anaconda3\lib\site-packages (from html5lib<2.0,>=1.1->soccerdata) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\arjun\anaconda3\lib\site-packages (from html5lib<2.0,>=1.1->soccerdata) (0.5.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\arjun\anaconda3\lib\site-packages (from pandas!=2.1.0,<3.0.0,>=2.0.0->soccerdata) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arjun\anaconda3\lib\site-packages (from pandas!=2.1.0,<3.0.0,>=2.0.0->soccerdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arjun\anaconda3\lib\site-packages (from pandas!=2.1.0,<3.0.0,>=2.0.0->soccerdata) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arjun\anaconda3\lib\site-packages (from pandas!=2.1.0,<3.0.0,>=2.0.0->soccerdata) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arjun\anaconda3\lib\site-packages (from requests<3.0,>=2.23->soccerdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arjun\anaconda3\lib\site-packages (from requests<3.0,>=2.23->soccerdata) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arjun\anaconda3\lib\site-packages (from requests<3.0,>=2.23->soccerdata) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arjun\anaconda3\lib\site-packages (from requests<3.0,>=2.23->soccerdata) (2025.7.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\arjun\anaconda3\lib\site-packages (from rich<14.0.0,>=13.0.0->soccerdata) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\arjun\anaconda3\lib\site-packages (from rich<14.0.0,>=13.0.0->soccerdata) (2.15.1)
# Requirement already satisfied: selenium>=4.9.0 in c:\users\arjun\anaconda3\lib\site-packages (from undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (4.34.2)
# Requirement already satisfied: websockets in c:\users\arjun\anaconda3\lib\site-packages (from undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (15.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\arjun\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->soccerdata) (0.1.0)
# Requirement already satisfied: trio~=0.30.0 in c:\users\arjun\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in c:\users\arjun\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.14.0 in c:\users\arjun\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\arjun\anaconda3\lib\site-packages (from selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\arjun\anaconda3\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (25.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\arjun\anaconda3\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (2.4.0)
# Requirement already satisfied: outcome in c:\users\arjun\anaconda3\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\arjun\anaconda3\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\arjun\anaconda3\lib\site-packages (from trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\arjun\anaconda3\lib\site-packages (from trio-websocket~=0.12.2->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\arjun\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\arjun\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium>=4.9.0->undetected-chromedriver<4.0.0,>=3.5.0->soccerdata) (0.14.0)
# [07/10/25 17:30:06] INFO     No custom team name replacements found. You can configure these in       ]8;id=799054;file://C:\Users\arjun\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=891657;file://C:\Users\arjun\anaconda3\Lib\site-packages\soccerdata\_config.py#91\91]8;;\
#                              C:\Users\arjun\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=523886;file://C:\Users\arjun\anaconda3\Lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=211343;file://C:\Users\arjun\anaconda3\Lib\site-packages\soccerdata\_config.py#197\197]8;;\
#                              C:\Users\arjun\soccerdata\config\league_dict.json.

# %%
# Step 1: Fetch Stats
fb = FBref(leagues="ENG-Premier League", seasons="2024-2025")

standard = fb.read_player_season_stats(stat_type="standard")
shooting = fb.read_player_season_stats(stat_type="shooting")
passing = fb.read_player_season_stats(stat_type="passing")
possession = fb.read_player_season_stats(stat_type="possession")
defense = fb.read_player_season_stats(stat_type="defense")

# Step 2: Reset Index to Expose 'Player' and 'Squad' Columns
for df in [standard, shooting, passing, possession, defense]:
    df.reset_index(inplace=True)

# Step 3: Filter for Forwards using Position Column
# 'Pos' column is found in the 'Standard' stats
strikers = standard[standard[('pos', '')] == 'FW'].copy()

# Step 4: Merge All Stats into Strikers Table (exclude re-merging with standard)
def merge_stats(df, new_df):
    return df.merge(new_df, on=['player', 'team'], suffixes=(None, f'_dup'))

strikers = merge_stats(strikers, shooting)
strikers = merge_stats(strikers, passing)
strikers = merge_stats(strikers, possession)
strikers = merge_stats(strikers, defense)
# Out:
# [07/10/25 18:01:26] INFO     Saving cached data to C:\Users\arjun\soccerdata\data\FBref              ]8;id=77263;file://C:\Users\arjun\anaconda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=526979;file://C:\Users\arjun\anaconda3\Lib\site-packages\soccerdata\_common.py#263\263]8;;\

# %%
print(strikers.columns.tolist())
# Out:
# [('league', ''), ('season', ''), ('team', ''), ('player', ''), ('nation', ''), ('pos', ''), ('age', ''), ('born', ''), ('Playing Time', 'MP'), ('Playing Time', 'Starts'), ('Playing Time', 'Min'), ('Playing Time', '90s'), ('Performance', 'Gls'), ('Performance', 'Ast'), ('Performance', 'G+A'), ('Performance', 'G-PK'), ('Performance', 'PK'), ('Performance', 'PKatt'), ('Performance', 'CrdY'), ('Performance', 'CrdR'), ('Expected', 'xG'), ('Expected', 'npxG'), ('Expected', 'xAG'), ('Expected', 'npxG+xAG'), ('Progression', 'PrgC'), ('Progression', 'PrgP'), ('Progression', 'PrgR'), ('Per 90 Minutes', 'Gls'), ('Per 90 Minutes', 'Ast'), ('Per 90 Minutes', 'G+A'), ('Per 90 Minutes', 'G-PK'), ('Per 90 Minutes', 'G+A-PK'), ('Per 90 Minutes', 'xG'), ('Per 90 Minutes', 'xAG'), ('Per 90 Minutes', 'xG+xAG'), ('Per 90 Minutes', 'npxG'), ('Per 90 Minutes', 'npxG+xAG'), ('league_dup', ''), ('season_dup', ''), ('nation_dup', ''), ('pos_dup', ''), ('age_dup', ''), ('born_dup', ''), ('90s', ''), ('Standard', 'Gls'), ('Standard', 'Sh'), ('Standard', 'SoT'), ('Standard', 'SoT%'), ('Standard', 'Sh/90'), ('Standard', 'SoT/90'), ('Standard', 'G/Sh'), ('Standard', 'G/SoT'), ('Standard', 'Dist'), ('Standard', 'FK'), ('Standard', 'PK'), ('Standard', 'PKatt'), ('Expected_dup', 'xG'), ('Expected_dup', 'npxG'), ('Expected_dup', 'npxG/Sh'), ('Expected_dup', 'G-xG'), ('Expected_dup', 'np:G-xG'), ('league_dup', ''), ('season_dup', ''), ('nation_dup', ''), ('pos_dup', ''), ('age_dup', ''), ('born_dup', ''), ('90s_dup', ''), ('Total', 'Cmp'), ('Total', 'Att'), ('Total', 'Cmp%'), ('Total', 'TotDist'), ('Total', 'PrgDist'), ('Short', 'Cmp'), ('Short', 'Att'), ('Short', 'Cmp%'), ('Medium', 'Cmp'), ('Medium', 'Att'), ('Medium', 'Cmp%'), ('Long', 'Cmp'), ('Long', 'Att'), ('Long', 'Cmp%'), ('Ast', ''), ('xAG', ''), ('Expected', 'xA'), ('Expected', 'A-xAG'), ('KP', ''), ('1/3', ''), ('PPA', ''), ('CrsPA', ''), ('PrgP', ''), ('league_dup', ''), ('season_dup', ''), ('nation_dup', ''), ('pos_dup', ''), ('age_dup', ''), ('born_dup', ''), ('90s_dup', ''), ('Touches', 'Touches'), ('Touches', 'Def Pen'), ('Touches', 'Def 3rd'), ('Touches', 'Mid 3rd'), ('Touches', 'Att 3rd'), ('Touches', 'Att Pen'), ('Touches', 'Live'), ('Take-Ons', 'Att'), ('Take-Ons', 'Succ'), ('Take-Ons', 'Succ%'), ('Take-Ons', 'Tkld'), ('Take-Ons', 'Tkld%'), ('Carries', 'Carries'), ('Carries', 'TotDist'), ('Carries', 'PrgDist'), ('Carries', 'PrgC'), ('Carries', '1/3'), ('Carries', 'CPA'), ('Carries', 'Mis'), ('Carries', 'Dis'), ('Receiving', 'Rec'), ('Receiving', 'PrgR'), ('league_dup', ''), ('season_dup', ''), ('nation_dup', ''), ('pos_dup', ''), ('age_dup', ''), ('born_dup', ''), ('90s_dup', ''), ('Tackles', 'Tkl'), ('Tackles', 'TklW'), ('Tackles', 'Def 3rd'), ('Tackles', 'Mid 3rd'), ('Tackles', 'Att 3rd'), ('Challenges', 'Tkl'), ('Challenges', 'Att'), ('Challenges', 'Tkl%'), ('Challenges', 'Lost'), ('Blocks', 'Blocks'), ('Blocks', 'Sh'), ('Blocks', 'Pass'), ('Int', ''), ('Tkl+Int', ''), ('Clr', ''), ('Err', '')]

# %%
# Flatten columns
strikers.columns = ['_'.join(filter(None, map(str, col))).strip() for col in strikers.columns.values]

# Replace 'Playing Time_90s' with a variable
per90_col = 'Playing Time_90s'

cols_to_per90_flat = [
    'Touches_Att Pen',
    'Carries_PrgC',
    'Carries_Carries',
    'Carries_PrgDist',
    'Tackles_Tkl',
    'Challenges_Tkl',
    'Take-Ons_Att',
    'Take-Ons_Succ',
]

for col in cols_to_per90_flat:
    new_col = col + '_per90'
    strikers[new_col] = strikers[col] / strikers[per90_col]

# Use new flat column names in your features list
features = [
    'Standard_Sh/90',
    'Per 90 Minutes_Gls',
    'Per 90 Minutes_xG',
    'Per 90 Minutes_Ast',
    'Per 90 Minutes_xAG',
    'Touches_Att Pen_per90',
    'Carries_PrgC_per90',
    'Carries_Carries_per90',
    'Carries_PrgDist_per90',
    'Tackles_Tkl_per90',
    'Challenges_Tkl_per90',
    'Take-Ons_Att_per90',
    'Take-Ons_Succ_per90',
]

# %%
cols_to_per90 = [
    ('Touches', 'Att Pen'),
    ('Carries', 'PrgC'),
    ('Carries', 'Carries'),
    ('Carries', 'PrgDist'),
    ('Tackles', 'Tkl'),
    ('Challenges', 'Tkl'),
    ('Take-Ons', 'Att'),
    ('Take-Ons', 'Succ'),
]

for col in cols_to_per90:
    new_col = (col[0], col[1] + '_per90')
    strikers[new_col] = strikers.loc[:, col] / strikers.loc[:, ('Playing Time', '90s')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13504\2056265118.py in ?()
#      10 ]
#      11
#      12 for col in cols_to_per90:
#      13     new_col = (col[0], col[1] + '_per90')
# ---> 14     strikers[new_col] = strikers.loc[:, col] / strikers.loc[:, ('Playing Time', '90s')]
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4455
#    4456             return self.isetitem(locs, value)
#    4457
#    4458         if len(value.columns) > 1:
# -> 4459             raise ValueError(
#    4460                 "Cannot set a DataFrame with multiple columns to the single "
#    4461                 f"column {key}"
#    4462             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column ('Touches', 'Att Pen_per90')

# %%
strikers.head()
# Out:
#                league season         team                 player nation pos  \
# 0  ENG-Premier League   2425      Arsenal          Gabriel Jesus    BRA  FW
# 1  ENG-Premier League   2425      Arsenal       Leandro Trossard    BEL  FW
# 2  ENG-Premier League   2425      Arsenal  Nathan Butler-Oyedeji    ENG  FW
# 3  ENG-Premier League   2425      Arsenal           Reiss Nelson    ENG  FW
# 4  ENG-Premier League   2425  Aston Villa          Donyell Malen    NED  FW
#
#    age  born  Playing Time_MP  Playing Time_Starts  Playing Time_Min  \
# 0   27  1997               17                    6               608
# 1   29  1994               38                   28              2546
# 2   21  2003                1                    0                 7
# 3   24  1999                1                    0                 3
# 4   25  1999               14                    2               305
#
#    Playing Time_90s  Performance_Gls  Performance_Ast  Performance_G+A  \
# 0              6.80                3                0                3
# 1             28.30                8                7               15
# 2              0.10                0                0                0
# 3              0.00                0                0                0
# 4              3.40                3                0                3
#
#    Performance_G-PK  Performance_PK  Performance_PKatt  Performance_CrdY  \
# 0                 3               0                  0                 4
# 1                 8               0                  0                 4
# 2                 0               0                  0                 0
# 3                 0               0                  0                 0
# 4                 3               0                  0                 0
#
#    Performance_CrdR  Expected_xG  Expected_npxG  Expected_xAG  \
# 0                 0         3.00           3.00          0.70
# 1                 1         7.20           7.20          6.10
# 2                 0         0.10           0.10          0.00
# 3                 0         0.00           0.00          0.00
# 4                 0         2.20           2.20          0.20
#
#    Expected_npxG+xAG  Progression_PrgC  Progression_PrgP  Progression_PrgR  \
# 0               3.70                15                19                57
# 1              13.30                80               101               226
# 2               0.10                 0                 0                 0
# 3               0.00                 0                 0                 0
# 4               2.40                12                 6                30
#
#    Per 90 Minutes_Gls  Per 90 Minutes_Ast  Per 90 Minutes_G+A  \
# 0                0.44                0.00                0.44
# 1                0.28                0.25                0.53
# 2                0.00                0.00                0.00
# 3                0.00                0.00                0.00
# 4                0.89                0.00                0.89
#
#    Per 90 Minutes_G-PK  Per 90 Minutes_G+A-PK  Per 90 Minutes_xG  \
# 0                 0.44                   0.44               0.44
# 1                 0.28                   0.53               0.25
# 2                 0.00                   0.00               0.94
# 3                 0.00                   0.00               0.00
# 4                 0.89                   0.89               0.64
#
#    Per 90 Minutes_xAG  Per 90 Minutes_xG+xAG  Per 90 Minutes_npxG  \
# 0                0.10                   0.54                 0.44
# 1                0.22                   0.47                 0.25
# 2                0.00                   0.94                 0.94
# 3                0.00                   0.00                 0.00
# 4                0.05                   0.69                 0.64
#
#    Per 90 Minutes_npxG+xAG          league_dup season_dup nation_dup pos_dup  \
# 0                     0.54  ENG-Premier League       2425        BRA      FW
# 1                     0.47  ENG-Premier League       2425        BEL      FW
# 2                     0.94  ENG-Premier League       2425        ENG      FW
# 3                     0.00  ENG-Premier League       2425        ENG      FW
# 4                     0.69  ENG-Premier League       2425        NED      FW
#
#    age_dup  born_dup   90s  Standard_Gls  Standard_Sh  Standard_SoT  \
# 0       27      1997  6.80             3           20             7
# 1       29      1994 28.30             8           72            21
# 2       21      2003  0.10             0            1             1
# 3       24      1999  <NA>             0            0             0
# 4       25      1999  3.40             3           15             9
#
#    Standard_SoT%  Standard_Sh/90  Standard_SoT/90  Standard_G/Sh  \
# 0          35.00            2.96             1.04           0.15
# 1          29.20            2.55             0.74           0.11
# 2         100.00           12.86            12.86           0.00
# 3           <NA>            0.00             0.00           <NA>
# 4          60.00            4.43             2.66           0.20
#
#    Standard_G/SoT  Standard_Dist  Standard_FK  Standard_PK  Standard_PKatt  \
# 0            0.43          11.10            0            0               0
# 1            0.38          15.90            0            0               0
# 2            0.00          15.60            0            0               0
# 3            <NA>           <NA>            0            0               0
# 4            0.33          15.20            0            0               0
#
#    Expected_dup_xG  Expected_dup_npxG  Expected_dup_npxG/Sh  \
# 0             3.00               3.00                  0.15
# 1             7.20               7.20                  0.10
# 2             0.10               0.10                  0.07
# 3             0.00               0.00                  <NA>
# 4             2.20               2.20                  0.14
#
#    Expected_dup_G-xG  Expected_dup_np:G-xG          league_dup season_dup  \
# 0               0.00                  0.00  ENG-Premier League       2425
# 1               0.80                  0.80  ENG-Premier League       2425
# 2              -0.10                 -0.10  ENG-Premier League       2425
# 3               0.00                  0.00  ENG-Premier League       2425
# 4               0.80                  0.80  ENG-Premier League       2425
#
#   nation_dup pos_dup  age_dup  born_dup  90s_dup  Total_Cmp  Total_Att  \
# 0        BRA      FW       27      1997     6.80        156        203
# 1        BEL      FW       29      1994    28.30        711        954
# 2        ENG      FW       21      2003     0.10          0          0
# 3        ENG      FW       24      1999     0.00          0          0
# 4        NED      FW       25      1999     3.40         53         77
#
#    Total_Cmp%  Total_TotDist  Total_PrgDist  Short_Cmp  Short_Att  Short_Cmp%  \
# 0       76.80           2030            378        103        128       80.50
# 1       74.50          11435           2972        377        439       85.90
# 2        <NA>              0              0          0          0        <NA>
# 3        <NA>              0              0          0          0        <NA>
# 4       68.80            712            144         33         40       82.50
#
#    Medium_Cmp  Medium_Att  Medium_Cmp%  Long_Cmp  Long_Att  Long_Cmp%  Ast  \
# 0          41          47        87.20         4         6      66.70    0
# 1         275         357        77.00        43        87      49.40    7
# 2           0           0         <NA>         0         0       <NA>    0
# 3           0           0         <NA>         0         0       <NA>    0
# 4          14          19        73.70         3         7      42.90    0
#
#    xAG  Expected_xA  Expected_A-xAG  KP  1/3  PPA  CrsPA  PrgP  \
# 0 0.70         0.50           -0.70   8   10    9      1    19
# 1 6.10         4.10            0.90  41   45   48     10   101
# 2 0.00         0.00            0.00   0    0    0      0     0
# 3 0.00         0.00            0.00   0    0    0      0     0
# 4 0.20         0.20           -0.20   3    2    2      0     6
#
#            league_dup season_dup nation_dup pos_dup  age_dup  born_dup  \
# 0  ENG-Premier League       2425        BRA      FW       27      1997
# 1  ENG-Premier League       2425        BEL      FW       29      1994
# 2  ENG-Premier League       2425        ENG      FW       21      2003
# 3  ENG-Premier League       2425        ENG      FW       24      1999
# 4  ENG-Premier League       2425        NED      FW       25      1999
#
#    90s_dup  Touches_Touches  Touches_Def Pen  Touches_Def 3rd  \
# 0     6.80              299                9               28
# 1    28.30             1278               17              135
# 2     0.10                1                0                0
# 3     0.00                2                0                1
# 4     3.40              129                2                9
#
#    Touches_Mid 3rd  Touches_Att 3rd  Touches_Att Pen  Touches_Live  \
# 0              108              165               48           299
# 1              399              762              158          1278
# 2                0                1                1             1
# 3                1                0                0             2
# 4               33               94               25           129
#
#    Take-Ons_Att  Take-Ons_Succ  Take-Ons_Succ%  Take-Ons_Tkld  Take-Ons_Tkld%  \
# 0            22              9           40.90             10           45.50
# 1            86             38           44.20             37           43.00
# 2             0              0            <NA>              0            <NA>
# 3             0              0            <NA>              0            <NA>
# 4            11              4           36.40              5           45.50
#
#    Carries_Carries  Carries_TotDist  Carries_PrgDist  Carries_PrgC  \
# 0              179              953              432            15
# 1              828             5024             2218            80
# 2                0                0                0             0
# 3                1                4                4             0
# 4               79              652              370            12
#
#    Carries_1/3  Carries_CPA  Carries_Mis  Carries_Dis  Receiving_Rec  \
# 0            6           11           13           13            217
# 1           55           30           66           52            956
# 2            0            0            0            0              0
# 3            0            0            0            0              1
# 4            7            7            8            7             87
#
#    Receiving_PrgR          league_dup season_dup nation_dup pos_dup  age_dup  \
# 0              57  ENG-Premier League       2425        BRA      FW       27
# 1             226  ENG-Premier League       2425        BEL      FW       29
# 2               0  ENG-Premier League       2425        ENG      FW       21
# 3               0  ENG-Premier League       2425        ENG      FW       24
# 4              30  ENG-Premier League       2425        NED      FW       25
#
#    born_dup  90s_dup  Tackles_Tkl  Tackles_TklW  Tackles_Def 3rd  \
# 0      1997     6.80           10             6                4
# 1      1994    28.30           31            20                6
# 2      2003     0.10            0             0                0
# 3      1999     0.00            1             0                0
# 4      1999     3.40            7             4                3
#
#    Tackles_Mid 3rd  Tackles_Att 3rd  Challenges_Tkl  Challenges_Att  \
# 0                3                3               4               9
# 1               16                9              12              34
# 2                0                0               0               0
# 3                1                0               0               1
# 4                3                1               1               4
#
#    Challenges_Tkl%  Challenges_Lost  Blocks_Blocks  Blocks_Sh  Blocks_Pass  \
# 0            44.40                5             10          1            9
# 1            35.30               22             32          0           32
# 2             <NA>                0              0          0            0
# 3             0.00                1              0          0            0
# 4            25.00                3              2          0            2
#
#    Int  Tkl+Int  Clr  Err  Touches_Att Pen_per90  Carries_PrgC_per90  \
# 0    4       14    8    0                   7.06                2.21
# 1    9       40   18    0                   5.58                2.83
# 2    0        0    0    0                  10.00                0.00
# 3    0        1    1    0                    NaN                 NaN
# 4    0        7    1    0                   7.35                3.53
#
#    Carries_Carries_per90  Carries_PrgDist_per90  Tackles_Tkl_per90  \
# 0                  26.32                  63.53               1.47
# 1                  29.26                  78.37               1.10
# 2                   0.00                   0.00               0.00
# 3                    inf                    inf                inf
# 4                  23.24                 108.82               2.06
#
#    Challenges_Tkl_per90  Take-Ons_Att_per90  Take-Ons_Succ_per90
# 0                  0.59                3.24                 1.32
# 1                  0.42                3.04                 1.34
# 2                  0.00                0.00                 0.00
# 3                   NaN                 NaN                  NaN
# 4                  0.29                3.24                 1.18

# %%
strikers = strikers[strikers[('Playing Time_90s')] >= 5].copy()
strikers[('Playing Time_90s')] = strikers[('Playing Time_90s')].replace(0, np.nan)

# %%
print(np.isinf(strikers_clean[features]).sum())  # counts of infinite values per column
# Out:
# Standard_Sh/90           0
# Per 90 Minutes_Gls       0
# Per 90 Minutes_xG        0
# Per 90 Minutes_Ast       0
# Per 90 Minutes_xAG       0
# Touches_Att Pen_per90    0
# Carries_PrgC_per90       0
# Carries_Carries_per90    0
# Carries_PrgDist_per90    0
# Tackles_Tkl_per90        0
# Challenges_Tkl_per90     0
# Take-Ons_Att_per90       0
# Take-Ons_Succ_per90      0
# dtype: Int32

# %%
strikers_clean = strikers.dropna(subset=features).copy()

# Step 6: Normalize Features
scaler = StandardScaler()
X = scaler.fit_transform(strikers_clean[features])

# Step 7: KMeans Clustering
kmeans = KMeans(n_clusters=4, random_state=42)
strikers_clean['cluster'] = kmeans.fit_predict(X)

# Step 8: Visualize Cluster Centers
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=features)

plt.figure(figsize=(12, 6))
sns.heatmap(centroids, annot=True, cmap="coolwarm", yticklabels=[f"Cluster {i}" for i in range(4)])
plt.title("Striker Style Clusters (Flattened Features)")
plt.show()

# Step 9: Inspect Clustered Players
cols_to_show = ['player', 'team', 'cluster'] + features

# %%
strikers_clean[cols_to_show].sort_values('cluster').head(50)
# Out:
#                    player             team  cluster  Standard_Sh/90  \
# 46          Kasey McAteer   Leicester City        0            1.37
# 42  Abdul Fatawu Issahaku   Leicester City        0            2.02
# 77             Mathys Tel        Tottenham        0            2.17
# 36           Reiss Nelson           Fulham        0            2.22
# 34       Jesper Lindstrøm          Everton        0            2.03
# 33          Jack Harrison          Everton        0            1.26
# 32          Iliman Ndiaye          Everton        0            1.30
# 21           Jadon Sancho          Chelsea        0            1.22
# 65           Jacob Murphy    Newcastle Utd        0            1.64
# 48        Stephy Mavididi   Leicester City        0            1.45
# 26             Pedro Neto          Chelsea        0            2.34
# 0           Gabriel Jesus          Arsenal        1            2.96
# 52             Diogo Jota        Liverpool        1            3.84
# 54              Luis Díaz        Liverpool        1            2.66
# 62         Alexander Isak    Newcastle Utd        1            3.10
# 64          Harvey Barnes    Newcastle Utd        1            3.23
# 50             Cody Gakpo        Liverpool        1            2.65
# 20     Christopher Nkunku          Chelsea        1            2.44
# 14           Bryan Mbeumo        Brentford        1            2.08
# 9          Dango Ouattara      Bournemouth        1            2.78
# 8         Antoine Semenyo      Bournemouth        1            3.51
# 1        Leandro Trossard          Arsenal        1            2.55
# 25           Noni Madueke          Chelsea        1            3.54
# 68             Chris Wood  Nott'ham Forest        2            1.98
# 71         Cameron Archer      Southampton        2            1.75
# 73           Paul Onuachu      Southampton        2            2.91
# 75        Brennan Johnson        Tottenham        2            2.23
# 76        Dominic Solanke        Tottenham        2            2.41
# 61         Rasmus Højlund   Manchester Utd        2            1.44
# 58         Erling Haaland  Manchester City        2            3.42
# 79            Richarlison        Tottenham        2            3.04
# 82        Michail Antonio         West Ham        2            2.05
# 70           Ben Brereton      Southampton        2            2.20
# 41             Liam Delap     Ipswich Town        2            2.29
# 45            Jamie Vardy   Leicester City        2            1.79
# 5             Jáder Durán      Aston Villa        2            4.37
# 7           Ollie Watkins      Aston Villa        2            2.84
# 11              Evanilson      Bournemouth        2            2.79
# 15           Kevin Schade        Brentford        2            2.16
# 16            Yoane Wissa        Brentford        2            2.77
# 17          Danny Welbeck         Brighton        2            2.51
# 24        Nicolas Jackson          Chelsea        2            3.08
# 51           Darwin Núñez        Liverpool        2            2.70
# 28   Jean-Philippe Mateta   Crystal Palace        2            2.31
# 31  Dominic Calvert-Lewin          Everton        2            2.80
# 35           Raúl Jiménez           Fulham        2            3.36
# 37          Rodrigo Muniz           Fulham        2            3.64
# 40           George Hirst     Ipswich Town        2            1.91
# 83        Niclas Füllkrug         West Ham        2            1.82
# 43  Bobby De Cordova-Reid   Leicester City        2            0.85
#
#     Per 90 Minutes_Gls  Per 90 Minutes_xG  Per 90 Minutes_Ast  \
# 46                0.11               0.11                0.11
# 42                0.00               0.06                0.31
# 77                0.20               0.29                0.10
# 36                0.18               0.20                0.18
# 34                0.00               0.15                0.07
# 33                0.04               0.15                0.00
# 32                0.33               0.23                0.00
# 21                0.15               0.11                0.20
# 65                0.31               0.22                0.46
# 48                0.22               0.10                0.06
# 26                0.16               0.14                0.24
# 0                 0.44               0.44                0.00
# 52                0.45               0.60                0.23
# 54                0.49               0.45                0.19
# 62                0.75               0.66                0.20
# 64                0.46               0.37                0.21
# 50                0.47               0.33                0.19
# 20                0.29               0.47                0.20
# 14                0.53               0.32                0.18
# 9                 0.31               0.38                0.18
# 8                 0.31               0.28                0.14
# 1                 0.28               0.25                0.25
# 25                0.31               0.43                0.13
# 68                0.61               0.41                0.09
# 71                0.12               0.36                0.00
# 73                0.34               0.31                0.09
# 75                0.45               0.43                0.12
# 76                0.37               0.45                0.12
# 61                0.18               0.24                0.00
# 58                0.72               0.72                0.10
# 79                0.71               0.66                0.18
# 82                0.11               0.24                0.11
# 70                0.00               0.18                0.00
# 41                0.42               0.32                0.07
# 45                0.29               0.36                0.13
# 5                 0.99               0.69                0.00
# 7                 0.55               0.53                0.28
# 11                0.39               0.48                0.04
# 15                0.43               0.32                0.08
# 16                0.59               0.57                0.12
# 17                0.43               0.41                0.17
# 24                0.41               0.50                0.20
# 51                0.40               0.46                0.16
# 28                0.48               0.46                0.07
# 31                0.17               0.38                0.06
# 35                0.43               0.43                0.11
# 37                0.75               0.54                0.09
# 40                0.41               0.29                0.14
# 83                0.34               0.25                0.23
# 43                0.12               0.10                0.24
#
#     Per 90 Minutes_xAG  Touches_Att Pen_per90  Carries_PrgC_per90  \
# 46                0.08                   3.16                2.00
# 42                0.24                   4.06                6.56
# 77                0.25                   3.96                2.77
# 36                0.18                   6.48                8.33
# 34                0.15                   2.90                2.17
# 33                0.16                   2.99                3.16
# 32                0.07                   3.07                3.19
# 21                0.19                   6.17                5.20
# 65                0.34                   3.51                3.02
# 48                0.15                   3.41                5.08
# 26                0.27                   4.60                5.00
# 0                 0.10                   7.06                2.21
# 52                0.14                   7.29                2.78
# 54                0.19                   6.25                4.04
# 62                0.14                   6.18                2.71
# 64                0.20                   6.56                4.77
# 50                0.20                   5.12                2.74
# 20                0.21                   5.10                1.67
# 14                0.22                   4.43                3.43
# 9                 0.25                   5.74                3.54
# 8                 0.16                   5.37                3.93
# 1                 0.22                   5.58                2.83
# 25                0.19                   8.14                6.81
# 68                0.08                   3.19                0.43
# 71                0.03                   3.25                1.38
# 73                0.04                   5.73                0.60
# 75                0.09                   5.17                2.48
# 76                0.12                   4.57                1.27
# 61                0.08                   3.32                1.26
# 58                0.10                   6.25                0.79
# 79                0.16                   5.18                1.43
# 82                0.17                   3.87                3.12
# 70                0.02                   4.00                2.40
# 41                0.07                   3.19                2.12
# 45                0.10                   3.54                0.92
# 5                 0.03                   6.62                0.99
# 7                 0.12                   5.81                1.90
# 11                0.07                   4.92                1.12
# 15                0.14                   5.73                2.39
# 16                0.08                   5.03                1.85
# 17                0.06                   4.34                0.89
# 24                0.17                   5.71                1.90
# 51                0.10                   5.87                1.83
# 28                0.11                   3.20                1.53
# 31                0.04                   4.92                1.28
# 35                0.12                   5.96                1.26
# 37                0.07                   5.14                0.56
# 40                0.05                   3.84                1.23
# 83                0.22                   4.55                0.80
# 43                0.15                   1.93                1.69
#
#     Carries_Carries_per90  Carries_PrgDist_per90  Tackles_Tkl_per90  \
# 46                  23.58                  60.53               2.42
# 42                  33.91                 164.84               3.28
# 77                  26.34                  79.70               1.58
# 36                  47.96                 177.78               1.48
# 34                  21.88                  56.52               3.26
# 33                  22.68                  70.95               1.39
# 32                  23.00                  87.67               1.96
# 21                  33.32                 124.23               0.66
# 65                  27.98                  89.27               1.07
# 48                  32.57                 131.56               1.90
# 26                  29.60                 132.62               0.91
# 0                   26.32                  63.53               1.47
# 52                  19.77                  59.85               1.05
# 54                  29.21                 110.86               1.46
# 62                  20.10                  60.82               0.39
# 64                  28.77                 126.51               0.82
# 50                  28.14                 102.70               1.30
# 20                  27.45                  61.57               1.18
# 14                  28.42                  92.85               1.29
# 9                   22.06                  79.69               1.57
# 8                   27.50                 100.59               1.54
# 1                   29.26                  78.37               1.10
# 25                  28.36                 154.20               1.11
# 68                  11.43                  15.38               0.18
# 71                  14.12                  35.25               0.81
# 73                  18.29                  21.20               0.60
# 75                  22.48                  60.33               1.61
# 76                  15.71                  34.61               0.73
# 61                  13.81                  29.37               0.13
# 58                  10.20                  18.98               0.36
# 79                  15.89                  30.00               0.89
# 82                  18.60                  74.73               0.22
# 70                  27.20                  78.80               0.60
# 41                  15.45                  55.07               0.38
# 45                   9.08                  22.83               0.61
# 5                   18.73                  37.61               1.13
# 7                   14.15                  38.93               0.35
# 11                  12.91                  33.37               0.62
# 15                  17.02                  53.22               1.53
# 16                  16.98                  51.30               0.68
# 17                  19.06                  37.87               1.11
# 24                  16.88                  53.28               0.89
# 51                  15.95                  45.08               1.67
# 28                  13.61                  35.65               0.61
# 31                  15.64                  25.87               0.50
# 35                  19.82                  40.14               1.26
# 37                  14.67                  17.48               0.93
# 40                  13.84                  28.90               0.41
# 83                  13.98                  24.43               0.45
# 43                  20.96                  46.87               1.08
#
#     Challenges_Tkl_per90  Take-Ons_Att_per90  Take-Ons_Succ_per90
# 46                  1.47                2.63                 0.63
# 42                  1.72               10.78                 4.53
# 77                  0.50                5.25                 1.49
# 36                  0.93                6.48                 2.41
# 34                  1.38                3.12                 0.58
# 33                  0.65                3.25                 1.04
# 32                  0.81                5.30                 2.52
# 21                  0.26                4.95                 2.30
# 65                  0.76                2.63                 1.34
# 48                  0.78                5.31                 1.96
# 26                  0.36                4.13                 1.35
# 0                   0.59                3.24                 1.32
# 52                  0.53                2.48                 0.83
# 54                  0.56                4.34                 1.99
# 62                  0.16                2.97                 1.37
# 64                  0.15                3.28                 1.23
# 50                  0.60                2.84                 1.44
# 20                  0.59                2.65                 0.98
# 14                  0.55                2.93                 1.37
# 9                   0.76                3.68                 1.75
# 8                   0.45                3.79                 1.94
# 1                   0.42                3.04                 1.34
# 25                  0.62                4.51                 1.99
# 68                  0.09                0.40                 0.12
# 71                  0.12                2.31                 0.94
# 73                  0.26                2.22                 0.68
# 75                  0.66                1.82                 0.79
# 76                  0.16                2.08                 0.69
# 61                  0.00                1.48                 0.40
# 58                  0.10                1.18                 0.43
# 79                  0.00                2.86                 0.18
# 82                  0.22                2.90                 0.97
# 70                  0.20                0.80                 0.20
# 41                  0.07                2.99                 1.39
# 45                  0.13                0.73                 0.35
# 5                   0.14                1.97                 0.42
# 7                   0.10                1.42                 0.35
# 11                  0.31                0.81                 0.27
# 15                  0.51                3.49                 1.18
# 16                  0.34                1.51                 0.46
# 17                  0.34                1.57                 0.55
# 24                  0.20                2.47                 0.73
# 51                  0.56                1.83                 0.63
# 28                  0.10                1.56                 0.68
# 31                  0.11                1.40                 0.56
# 35                  0.29                1.81                 0.76
# 37                  0.37                1.68                 0.56
# 40                  0.14                0.82                 0.27
# 83                  0.34                0.91                 0.11
# 43                  0.48                1.20                 0.00

# %%
from sklearn.decomposition import PCA
# Reduce to 2 dimensions
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(25, 15))  # Wider and taller figure
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=strikers_clean['cluster'], cmap='tab10', alpha=0.7)

# Annotate some points (all or a sample)
for i, player in enumerate(strikers_clean['player']):
    plt.text(X_pca[i, 0], X_pca[i, 1], player, fontsize=8)

plt.colorbar(scatter, label='Cluster')
plt.title('Player Clusters Visualized with PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()
